# %% [markdown]
# Explanation of Credit Card Data Columns
# - CUST_ID: Unique identifier for each customer.
# - BALANCE: The current balance on the credit card.
# - BALANCE_FREQUENCY: The frequency of balance updates (score between 0 and 1).
# - PURCHASES: Total amount of purchases made on the card.
# - ONEOFF_PURCHASES: Total amount of one-time purchases.
# - INSTALLMENTS_PURCHASES: Total amount of purchases made in installments.
# - CASH_ADVANCE: Total amount of cash advances taken by the customer.
# - PURCHASES_FREQUENCY: The frequency of any purchases made by the customer (score between 0 and 1).
# - ONEOFF_PURCHASES_FREQUENCY: Frequency of one-time purchases (score between 0 and 1).
# - PURCHASES_INSTALLMENTS_FREQUENCY: Frequency of installment-based purchases (score between 0 and 1).
# - CASH_ADVANCE_FREQUENCY: Frequency of cash advances (score between 0 and 1).
# - CASH_ADVANCE_TRX: Number of transactions for cash advances.
# - PURCHASES_TRX: Number of purchase transactions made.
# - CREDIT_LIMIT: The credit limit assigned to the credit card.
# - PAYMENTS: Total payments made by the customer.
# - MINIMUM_PAYMENTS: Minimum payments made by the customer.
# - PRC_FULL_PAYMENT: Percentage of months where the customer paid the full balance.
# - TENURE: The number of months the customer has been using the credit card.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r"C:\Users\ksbuf\OneDrive\Desktop\School\Spring 2025\Data 5600\Group Projects\Project 1\data\credit_Dataset.csv")

df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df_trimmed = df[['ONEOFF_PURCHASES_FREQUENCY', 'CREDIT_LIMIT']].dropna()

# df_trimmed['CREDIT_LIMIT'] = np.log(df_trimmed['CREDIT_LIMIT'])

# df_trimmed['spending'] = np.sqrt(df_trimmed['spending'])
# Display the first few rows
df_trimmed.head(100)
# Out:
#     ONEOFF_PURCHASES_FREQUENCY  CREDIT_LIMIT
# 0                     0.000000        1000.0
# 1                     0.000000        7000.0
# 2                     1.000000        7500.0
# 3                     0.083333        7500.0
# 4                     0.083333        1200.0
# ..                         ...           ...
# 95                    0.000000        1200.0
# 96                    0.666667        6000.0
# 97                    0.000000        4000.0
# 98                    0.000000        7000.0
# 99                    0.000000        3000.0
#
# [100 rows x 2 columns]

# %%
# np.log(df_trimmed['CREDIT_LIMIT']).hist()
# Out:
# <Axes: >

# %%
# Create a scatterplot
plt.figure(figsize=(12, 8))
plt.scatter(df_trimmed['ONEOFF_PURCHASES_FREQUENCY'], df_trimmed['CREDIT_LIMIT'], color='blue', alpha=0.6)
plt.title('Balance and Cash Advances', fontsize=16)
plt.xlabel('Balance', fontsize=14)
plt.ylabel('Minimum Payments', fontsize=14)
plt.grid(True)
plt.show()

# %%
# Compute the correlation matrix
correlation_matrix = df_trimmed.corr()
print(correlation_matrix)
# Out:
#                             ONEOFF_PURCHASES_FREQUENCY  CREDIT_LIMIT
# ONEOFF_PURCHASES_FREQUENCY                    1.000000      0.295038
# CREDIT_LIMIT                                  0.295038      1.000000
